# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Belknap/austin_INFO5707_Spring2022/blob/main/lab_assignment_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third Lab-assignment (02/10/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here: Data is needed to perform realy price analysis in the Austin area. By collecting this data price per square foot can be calculated and compared across specific properties 
as well as by zip code. The goal is to be able to determine if a house is priced above or below market based on the price per square foot.





'''

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
from time import sleep

#assign the base url to 'realtor'
realtor = "https://www.realtor.com/realestateandhomes-search/Austin_TX/pg-"

#create a list of all of the url's necessary to find all of the Austin listings
realtor_urls = []
for i in range(1,38):
  realtor_urls.append(realtor + str(i))
print(realtor_urls)

#scrape the data from realtor.com
results = []
for url in realtor_urls:
   pages = urllib.request.Request(url, headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.11 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9', 'Accept-Encoding': 'identity'})
   sleep(5)
   infile = urllib.request.urlopen(pages).read()
   results.append(infile)

print(results)

#prettify the results
soup = BeautifulSoup(str(results))
print(soup.prettify())

#print the data points
for item in soup.select('.component_property-card'):
	try:
		#print('**********')
		#print(item)
		print(item.select('[data-label=pc-price]')[0].get_text())
		print(item.select('img')[0]['data-src'])
		print(item.select('.summary-wrap')[0].get_text())
		print(item.select('.address')[0].get_text())
		print(item.select('.property-meta')[0].get_text())
		print(item.select('.special-feature-list')[0].get_text())
		
	except Exception as e:
		#raise e
		print('')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-27-c850e3b9aeeb> in <module>()
#      17    pages = urllib.request.Request(url, headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.11 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9', 'Accept-Encoding': 'identity'})
#      18    sleep(5)
# ---> 19    infile = urllib.request.urlopen(pages).read()
#      20    results.append(infile)
#      21
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# /usr/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''

Please write you answer here: I used the following dataset: https://www.kaggle.com/nikdavis/steam-store-raw.
The dataset has missing values that should be removed. The number of missing values is not significant to the dataset. There are also null values that hurt the quality of the dataset and should be removed
because they are not useful. Columns with a large number of null values should be removed as well since they cannot add to any analysis of the data.





'''

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept
# normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
#
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all
# test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples
# from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors
# randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the
# ten folds.
#
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file
# and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially
# introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
#
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each
# phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
#
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all
# duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number
# of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
#
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
#
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair
# appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds
# dataset is used in all our experiments.
#
# (The original paper can be download on canvas)

# %%
# You code here (Please add comments in the code):
from google.colab import drive
drive.mount("/content/drive")

import os
import glob
import pandas as pd
import numpy as np

#We create lists of the files that need to be combined
folder1 = '/content/drive/MyDrive/datasets/medical_concepts_datasets/AskAPatient1/'
file_list1 = os.listdir(folder1)
print(file_list1)
folder2 = '/content/drive/MyDrive/datasets/medical_concepts_datasets/TwADR-L1/'
file_list2 = os.listdir(folder2)
print(file_list2)

#The files from each data set are compiled into a single file for each dataset
with open("/content/drive/MyDrive/datasets/medical_concepts_datasets/AskAPatient1/AskAPatient.fold-all.txt", "w") as outfile:
    for filename in file_list1:
        with open(folder1 + filename, encoding="utf8", errors='ignore') as infile:
            contents1 = infile.read()
            outfile.write(contents1)
with open("/content/drive/MyDrive/datasets/medical_concepts_datasets/TwADR-L1/TwADR-L.fold-all.txt", "w") as outfile:
    for filename in file_list2:
        with open(folder2 + filename, encoding="utf8", errors='ignore') as infile:
            contents2 = infile.read()
            outfile.write(contents2)

print(contents1)
print(contents2)

#The data frames are created and headings are added to each column
df1 = pd.read_csv("/content/drive/MyDrive/datasets/medical_concepts_datasets/AskAPatient1/AskAPatient.fold-all.txt", delimiter = "\t", names=["ID", "Concept", "Description"])
df2 = pd.read_csv("/content/drive/MyDrive/datasets/medical_concepts_datasets/TwADR-L1/TwADR-L.fold-all.txt", delimiter = "\t", names=["ID", "Concept", "Description"])

print(df1)
print(df2)

#Duplicate data is removed
print(df1.duplicated())
print(df2.duplicated())

df1.drop_duplicates(inplace = True)
df2.drop_duplicates(inplace = True) 

print(df1)
print(df2)

#Concepts are filtered by those with more than 5 instances
filtered_df1 = df1.groupby('Concept').filter(lambda x: len(x) >= 5)
filtered_df2 = df2.groupby('Concept').filter(lambda x: len(x) >= 5)
print(filtered_df1)
print(filtered_df2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Streaming output truncated to the last 5000 lines.
# C0233459	Emotional disorder	emotionally numb
# C0233459	Emotional disorder	Emotional disorder
# C1263846	Attention deficit hyperactivity disorder	Attention deficit hyperactivity disorder
# C0009676	Confusion	Confusion
# C0278061	Abnormal mental state	fucks me up
# C0278061	Abnormal mental state	Abnormal mental state
# C0005586	Bipolar Disorder	#bipolar
# C0005586	Bipolar Disorder	Bipolar Disorder
# C0085633	Mood swings	had me in my feelings
# C0085633	Mood swings	Mood swings
# C0041671	Attention Deficit Disorder	ADD
# C0041671	Attention Deficit Disorder	Attention Deficit Disorder
# C0151836	Paranoid reaction	paranoid
# C0151836	Paranoid reaction	Paranoid reaction
# C0235169	Excitability	in my feelings
# C0235169	Excitability	Excitability
# C1510472	Drug Dependence	my mom wont let me not take adderall i hate this
# C1510472	Drug Dependence	Drug Dependence
# C0087169	Withdrawal Symptoms	withdrawal symptoms
# C0087169	Withdrawal Symptoms	Withdrawal Symptoms
# C2939186	Disturbance in mood	Disturbance in mood
# C0525045	Mood Disorders	I'm crazy
# C0525045	Mood Disorders	Mood Disorders
# C0522172	Feeling drunk	feel drunk
# C0522172	Feeling drunk	Feeling drunk
# C1971624	Loss of appetite (finding)	barley eating
# C1971624	Loss of appetite (finding)	Loss of appetite (finding)
# C0003467	Anxiety	anxiety
# C0003467	Anxiety	Anxiety
# C0152031	Joint swelling	Joint was super swollen
# C0152031	Joint swelling	Joint swelling
# C0393761	Middle insomnia	keeping me awake
# C0393761	Middle insomnia	Middle insomnia
# C0220870	Lightheadedness	dizziness
# C0220870	Lightheadedness	Lightheadedness
# C0040822	Tremor	jitters
# C0040822	Tremor	Tremor
# C0235169	Excitability	got me to the ceiling
# C0235169	Excitability	Excitability
# C0424295	Hyperactive behavior	hyper
# C0424295	Hyperactive behavior	Hyperactive behavior
# C0234987	Dizziness postural	not falling down dizzy
# C0234987	Dizziness postural	Dizziness postural
# C0043387	Yawning	yawns
# C0043387	Yawning	Yawning
# C0541799	Bad taste	mouth taste terrible
# C0541799	Bad taste	Bad taste
# C0858899	Attention concentration difficulty	doesn't even make me attentive
# C0858899	Attention concentration difficulty	Attention concentration difficulty
# C0042256	Vaginal itching	Vaginal itching
# C0917801	Sleeplessness	Still awake
# C0917801	Sleeplessness	Sleeplessness
# C0917799	Hypersomnia	sleep for 16 hours a day
# C0917799	Hypersomnia	Hypersomnia
# C0278061	Abnormal mental state	bonkers
# C0278061	Abnormal mental state	Abnormal mental state
# C0043096	Body Weight decreased	weight loss
# C0043096	Body Weight decreased	Body Weight decreased
# C0393760	Initial insomnia	insomnia
# C0393760	Initial insomnia	Initial insomnia
# C0004936	Mental disorders	MY MIND IS GONE
# C0004936	Mental disorders	Mental disorders
# C0006370	Bulimia	bulimia
# C0006370	Bulimia	Bulimia
# C0005586	Bipolar Disorder	#bipolar
# C0005586	Bipolar Disorder	Bipolar Disorder
# C0541854	Daytime sleepiness	zombies
# C0541854	Daytime sleepiness	Daytime sleepiness
# C0004604	Back Pain	back ache
# C0004604	Back Pain	Back Pain
# C0000737	Abdominal Pain	pain in the pit of my stomach
# C0000737	Abdominal Pain	Abdominal Pain
# C0028643	Numbness	numbness
# C0028643	Numbness	Numbness
# C0235966	Dreaming excessive	#dreams whilst taking #Effexor are #crazy #messed up &amp; totally #weird
# C0235966	Dreaming excessive	Dreaming excessive
# C0700031	Anxiety attack	panic attacks
# C0700031	Anxiety attack	Anxiety attack
# C0086769	Panic Attacks	panic attacks
# C0086769	Panic Attacks	Panic Attacks
# C0541854	Daytime sleepiness	walking zombie
# C0541854	Daytime sleepiness	Daytime sleepiness
# C0043012	Wakefulness	still got me up
# C0043012	Wakefulness	Wakefulness
# C0086769	Panic Attacks	panic attack
# C0086769	Panic Attacks	Panic Attacks
# C0087169	Withdrawal Symptoms	withdrawals
# C0087169	Withdrawal Symptoms	Withdrawal Symptoms
# C0038587	Substance Withdrawal Syndrome	Substance Withdrawal Syndrome
# C0012833	Dizziness	head spinning a little
# C0012833	Dizziness	Dizziness
# C0344315	Depressed mood	shitty
# C0344315	Depressed mood	Depressed mood
# C0043012	Wakefulness	awake approx 36-38 hours
# C0043012	Wakefulness	Wakefulness
# C0003467	Anxiety	I'm scared
# C0003467	Anxiety	Anxiety
# C0030193	Pain	pain
# C0030193	Pain	Pain
# C0152128	Drug withdrawal syndrome	Drug withdrawal syndrome
# C0274714	Adrenergic syndrome	Adrenergic syndrome
# C0018772	Hearing Loss, Partial	Hearing Loss, Partial
# C0041466	Typhoid Fever	Typhoid Fever
# C0684249	Carcinoma of lung	Carcinoma of lung
# C0032961	Pregnancy	Pregnancy
# C0947912	Myasthenias	Myasthenias
# C0003578	Apnea	Apnea
# C1328504	Hormone-refractory prostate cancer	Hormone-refractory prostate cancer
# C0332601	Cushingoid facies	Cushingoid facies
# C0027726	Nephrotic Syndrome	Nephrotic Syndrome
# C0600125	Electrocardiogram PR prolongation	Electrocardiogram PR prolongation
# C0027720	Nephrosis	Nephrosis
# C0043352	Xerostomia	Xerostomia
# C0393761	Middle insomnia	Middle insomnia
# C0236826	Expressive language disorder	Expressive language disorder
# C0231835	Tachypnea	Tachypnea
# C0740425	Altered Taste	Altered Taste
# C0232831	Hyposthenuria	Hyposthenuria
# C0854530	Human herpesvirus 6 infection	Human herpesvirus 6 infection
# C0080274	Urinary Retention	Urinary Retention
# C0271298	Chemosis	Chemosis
# C0012359	Pathological Dilatation	Pathological Dilatation
# C0271051	Macular retinal edema	Macular retinal edema
# C1320474	Nuchal Rigidity	Nuchal Rigidity
# C0235240	Pounding heart	Pounding heart
# C0027651	Neoplasms	Neoplasms
# C0002170	Alopecia	Alopecia
# C0428977	Bradycardia	Bradycardia
# C0852388	Visual colour distortions	Visual colour distortions
# C0032781	Posterior rhinorrhea	Posterior rhinorrhea
# C1527407	Eosinophilic Pneumonia	Eosinophilic Pneumonia
# C0151934	Hypogeusia	Hypogeusia
# C0009443	Common Cold	Common Cold
# C0151936	Tendon disorder	Tendon disorder
# C0151937	Tendon rupture	Tendon rupture
# C0038454	Cerebrovascular accident	Cerebrovascular accident
# C0038450	Stridor	Stridor
# C0151752	FEMALE LACTATION	FEMALE LACTATION
# C0035258	Restless Legs Syndrome	Restless Legs Syndrome
# C0151205	Periorbital oedema	Periorbital oedema
# C0031190	Persistent Fetal Circulation Syndrome	Persistent Fetal Circulation Syndrome
# C3665418	Labile hypertension	Labile hypertension
# C0041601	Ulna Fractures	Ulna Fractures
# C0235025	Peripheral motor neuropathy	Peripheral motor neuropathy
# C0023434	Chronic Lymphocytic Leukemia	Chronic Lymphocytic Leukemia
# C0856623	Orofacial oedema	Orofacial oedema
# C0151686	Growth retardation	Growth retardation
# C1527311	Brain Edema	Brain Edema
# C0151689	Hair discoloration	Hair discoloration
# C0235750	Hypertension worsened	Hypertension worsened
# C0011849	Diabetes Mellitus	Diabetes Mellitus
# C0006277	Bronchitis	Bronchitis
# C0085740	Mendelson Syndrome	Mendelson Syndrome
# C0016053	Fibromyalgia	Fibromyalgia
# C0278106	Ejaculation failure	Ejaculation failure
# C0020569	Salivary gland enlargement	Salivary gland enlargement
# C0233973	Painful erection	Painful erection
# C0020564	Hypertrophy	Hypertrophy
# C0948807	Hepatic impairment	Hepatic impairment
# C0848309	Rhinitis perennial	Rhinitis perennial
# C0038587	Substance Withdrawal Syndrome	Substance Withdrawal Syndrome
# C0233407	Disorientation	Disorientation
# C0233401	Psychiatric symptom	Psychiatric symptom
# C0003028	Anhidrosis	Anhidrosis
# C0027080	Myoglobinuria	Myoglobinuria
# C0855227	Purging	Purging
# C0427108	General unsteadiness	General unsteadiness
# C1112709	Non-gonococcal urethritis (NGU)	Non-gonococcal urethritis (NGU)
# C0085692	Cystitis haemorrhagic	Cystitis haemorrhagic
# C1956346	Coronary Artery Disease	Coronary Artery Disease
# C0546947	Choking sensation	Choking sensation
# C0030552	Paresis	Paresis
# C0424109	Weepiness	Weepiness
# C0030554	Paresthesia	Paresthesia
# C0278079	Dependence psychological	Dependence psychological
# C0037672	Somnambulism	Somnambulism
# C0854069	Tumor pain	Tumor pain
# C0149756	Fasciitis, Plantar	Fasciitis, Plantar
# C3203661	Bilirubin total low	Bilirubin total low
# C0086981	Sicca Syndrome	Sicca Syndrome
# C0233571	Excitement emotion	Excitement emotion
# C0023890	Liver Cirrhosis	Liver Cirrhosis
# C0023895	Liver diseases	Liver diseases
# C0221423	Illness (finding)	Illness (finding)
# C0030486	Paraplegia	Paraplegia
# C0234376	Action Tremor	Action Tremor
# C0040896	Trichinellosis	Trichinellosis
# C0541832	Chromaturia	Chromaturia
# C0423153	Lacrimation	Lacrimation
# C0235807	Hair texture abnormal	Hair texture abnormal
# C0851341	Infestation	Infestation
# C0549209	Feeling jittery	Feeling jittery
# C0019557	Hip Fractures	Hip Fractures
# C0030318	Panic	Panic
# C0030319	Panic Disorder	Panic Disorder
# C0575090	Equilibration disorder	Equilibration disorder
# C0030312	Pancytopenia	Pancytopenia
# C0751295	Memory Loss	Memory Loss
# C1257843	Pseudomembranous colitis	Pseudomembranous colitis
# C0011206	Delirium	Delirium
# C0021167	Incontinence	Incontinence
# C0233754	Derealization	Derealization
# C0340238	Infectious disorder of bronchus	Infectious disorder of bronchus
# C0854082	Blood prolactin increased	Blood prolactin increased
# C0024440	Macular Edema, Cystoid	Macular Edema, Cystoid
# C0020701	Hysteria	Hysteria
# C0000727	Abdomen, Acute	Abdomen, Acute
# C0262405	Brain dysfunction	Brain dysfunction
# C0000729	Abdominal Cramps	Abdominal Cramps
# C0522172	Feeling drunk	Feeling drunk
# C0024282	Lymphocytosis	Lymphocytosis
# C0231837	Respiratory rate decreased	Respiratory rate decreased
# C0005758	Bulla	Bulla
# C0235939	Crying abnormal	Crying abnormal
# C0349410	Organ failure	Organ failure
# C0019158	Hepatitis	Hepatitis
# C0854303	Limb discomfort	Limb discomfort
# C0549250	Jaw stiffness	Jaw stiffness
# C0549253	Bladder dilatation	Bladder dilatation
# C0549259	Anxiety aggravated	Anxiety aggravated
# C0019156	Hepatic Veno-Occlusive Disease	Hepatic Veno-Occlusive Disease
# C0042256	Vaginal itching	Vaginal itching
# C0743300	Urine drug screen positive	Urine drug screen positive
# C0041296	Tuberculosis	Tuberculosis
# C0002962	Angina Pectoris	Angina Pectoris
# C0027531	Neck Injuries	Neck Injuries
# C0002965	Angina, Unstable	Angina, Unstable
# C0033575	Prostatic Diseases	Prostatic Diseases
# C0276141	Bronchitis viral	Bronchitis viral
# C0549336	Asthma aggravated	Asthma aggravated
# C0015695	Fatty Liver	Fatty Liver
# C0043037	Common wart	Common wart
# C0728936	Unspecified circulatory system disorder	Unspecified circulatory system disorder
# C0037320	Night Terrors	Night Terrors
# C0042035	Urination Disorders	Urination Disorders
# C0154731	Glossopharyngeal Neuralgia	Glossopharyngeal Neuralgia
# C0311468	Increased bilirubin level (finding)	Increased bilirubin level (finding)
# C0262578	Night cramps	Night cramps
# C0010038	Corneal Opacity	Corneal Opacity
# C0853714	Application site pruritus	Application site pruritus
# C0853711	Sperm count decreased	Sperm count decreased
# C0259972	Ketogenic Diet	Ketogenic Diet
# C1263960	Diabetes with coma (disorder)	Diabetes with coma (disorder)
# C0015967	Fever	Fever
# C0001418	Adenocarcinoma	Adenocarcinoma
# C0236051	Tolerance development	Tolerance development
# C0558489	Renal pain	Renal pain
# C0241863	Diabetic	Diabetic
# C0497201	Abnormal sensation in eye	Abnormal sensation in eye
# C0008728	Churg-Strauss Syndrome	Churg-Strauss Syndrome
# C0033774	Pruritus	Pruritus
# C0162848	Lichenoid Eruptions	Lichenoid Eruptions
# C0852711	Sickle Cell Dactylitis	Sickle Cell Dactylitis
# C0033771	Prurigo	Prurigo
# C0042109	Urticaria	Urticaria
# C0033778	Pruritus Vulvae	Pruritus Vulvae
# C0003813	Sinus Arrhythmia	Sinus Arrhythmia
# C0003811	Cardiac Arrhythmia	Cardiac Arrhythmia
# C0153690	Bone cancer metastatic	Bone cancer metastatic
# C1306577	Death (finding)	Death (finding)
# C0018991	Hemiplegia	Hemiplegia
# C0438717	Transaminases increased	Transaminases increased
# C0017086	Gangrene	Gangrene
# C0003486	Aortic Aneurysm	Aortic Aneurysm
# C0857980	Serum prolactin increased	Serum prolactin increased
# C0240327	Taste, Metallic	Taste, Metallic
# C0040213	Tietze's Syndrome	Tietze's Syndrome
# C0521495	Application site rash	Application site rash
# C0521490	Application site irritation	Application site irritation
# C0521491	Application site pain	Application site pain
# C0001511	Tissue Adhesions	Tissue Adhesions
# C0600139	Prostate carcinoma	Prostate carcinoma
# C0206669	Hepatocellular Adenoma	Hepatocellular Adenoma
# C0234975	Convulsions aggravated	Convulsions aggravated
# C0206063	Radiation Pneumonitis	Radiation Pneumonitis
# C0206062	Lung Diseases, Interstitial	Lung Diseases, Interstitial
# C0206061	Pneumonia, Interstitial	Pneumonia, Interstitial
# C0032227	Pleural effusion disorder	Pleural effusion disorder
# C0003962	Ascites	Ascites
# C1264613	Gastrointestinal infection	Gastrointestinal infection
# C0232807	Function kidney decreased	Function kidney decreased
# C2939420	Metastatic Neoplasm	Metastatic Neoplasm
# C0037822	Speech Disorders	Speech Disorders
# C0009760	Conjunctival haemorrhage	Conjunctival haemorrhage
# C0003708	Arachnoiditis	Arachnoiditis
# C1536459	Nettle rash	Nettle rash
# C0231230	Fatigability	Fatigability
# C0235234	Dry throat	Dry throat
# C0009450	Communicable Diseases	Communicable Diseases
# C0012833	Dizziness	Dizziness
# C0428974	Supraventricular arrhythmia	Supraventricular arrhythmia
# C0852911	Blood alkaline phosphatase increased	Blood alkaline phosphatase increased
# C0852913	Blood amylase increased	Blood amylase increased
# C0600228	Cardiopulmonary Arrest	Cardiopulmonary Arrest
# C0035243	Respiratory Tract Infections	Respiratory Tract Infections
# C1291077	Abdominal bloating	Abdominal bloating
# C1291078	Epigastric discomfort	Epigastric discomfort
# C0151740	Intracranial Hypertension	Intracranial Hypertension
# C0151746	Kidney function abnormal	Kidney function abnormal
# C0151744	Myocardial Ischemia	Myocardial Ischemia
# C0013298	Duodenitis	Duodenitis
# C0029442	Osteomalacia	Osteomalacia
# C0029443	Osteomyelitis	Osteomyelitis
# C0029445	Bone necrosis	Bone necrosis
# C0003635	Apraxias	Apraxias
# C0006285	Bronchopneumonia	Bronchopneumonia
# C0006846	Cutaneous Candidiasis	Cutaneous Candidiasis
# C0151691	High density lipoprotein decreased	High density lipoprotein decreased
# C0151692	Impaired healing	Impaired healing
# C0151694	Hemorrhage of colon	Hemorrhage of colon
# C1325847	Sensitisation	Sensitisation
# C0235347	Black hairy tongue	Black hairy tongue
# C2242583	Acute liver injury	Acute liver injury
# C0007642	Cellulitis	Cellulitis
# C0876994	Cardiotoxicity	Cardiotoxicity
# C0007398	Catatonia	Catatonia
# C0006266	Bronchial Spasm	Bronchial Spasm
# C0427008	Stiffness	Stiffness
# C0011053	Deafness	Deafness
# C0040409	Tongue Diseases	Tongue Diseases
# C0029191	Orchitis	Orchitis
# C0151541	Capillary fragility increased	Capillary fragility increased
# C0520893	Localized desquamation	Localized desquamation
# C0520459	Enterocolitis, Necrotizing	Enterocolitis, Necrotizing
# C0858899	Attention concentration difficulty	Attention concentration difficulty
# C0149922	Lichen Simplex Chronicus	Lichen Simplex Chronicus
# C0855217	Lack of spontaneous speech	Lack of spontaneous speech
# C0014547	Epilepsies, Partial	Epilepsies, Partial
# C0041105	Trismus	Trismus
# C0027092	Myopia	Myopia
# C0235165	Mania acute	Mania acute
# C0344320	Vivid dreams	Vivid dreams
# C0235168	Nervous tremulousness	Nervous tremulousness
# C0235169	Excitability	Excitability
# C0242362	Disk, Herniated	Disk, Herniated
# C2363722	Steroid psychosis	Steroid psychosis
# C0034074	Pulmonary Infarction	Pulmonary Infarction
# C0151754	Lactic dehydrogenase activity increased	Lactic dehydrogenase activity increased
# C0034040	Puerperal Disorders	Puerperal Disorders
# C0424448	Mask-like facies	Mask-like facies
# C0149725	Lower respiratory tract infection	Lower respiratory tract infection
# C0278008	Change of bowel habit	Change of bowel habit
# C0031542	Phlebitis	Phlebitis
# C0392185	Verbal repetition	Verbal repetition
# C0085641	Pustular rash	Pustular rash
# C0233697	Obsessions	Obsessions
# C0750197	Sustained ventricular tachycardia	Sustained ventricular tachycardia
# C0029261	Orgasmic Disorder	Orgasmic Disorder
# C0343863	Genital candidiasis	Genital candidiasis
# C0020175	Hunger	Hunger
# C0234369	Trembling	Trembling
# C0235763	Psoriasis flare-up	Psoriasis flare-up
# C0235761	Perforation of nasal septum	Perforation of nasal septum
# C0162565	Acute intermittent porphyria	Acute intermittent porphyria
# C0541820	Carbohydrate tolerance decreased	Carbohydrate tolerance decreased
# C0235834	Upper motor neurone lesion	Upper motor neurone lesion
# C0851353	Blood and lymphatic system disorders	Blood and lymphatic system disorders
# C0860703	Serum total protein decreased	Serum total protein decreased
# C0851354	Ear and labyrinth disorders	Ear and labyrinth disorders
# C0030305	Pancreatitis	Pancreatitis
# C0876973	Lung infection	Lung infection
# C0876975	Pruritus NEC	Pruritus NEC
# C0442886	Secondary Infections	Secondary Infections
# C0027697	Nephritis	Nephritis
# C0000731	Abdomen distended	Abdomen distended
# C0000737	Abdominal Pain	Abdominal Pain
# C0270736	Essential Tremor	Essential Tremor
# C0004610	Bacteremia	Bacteremia
# C0429097	QRS complex	QRS complex
# C0036689	Pharyngitis streptococcal	Pharyngitis streptococcal
# C0036337	Schizoaffective Disorder	Schizoaffective Disorder
# C0853891	Tumour flare	Tumour flare
# C0235901	Lacrimation abnormal	Lacrimation abnormal
# C0152009	WBC abnormal	WBC abnormal
# C0039520	Tenosynovitis	Tenosynovitis
# C0877237	Traumatic fracture	Traumatic fracture
# C0549249	Depressed Level of Consciousness	Depressed Level of Consciousness
# C1868709	Activation syndrome	Activation syndrome
# C0041912	Upper Respiratory Infections	Upper Respiratory Infections
# C1956089	Osteophyte	Osteophyte
# C0155067	Corneal ulcer marginal	Corneal ulcer marginal
# C0392162	Clammy skin	Clammy skin
# C0392163	Corneal erosion	Corneal erosion
# C0015371	Extrapyramidal Disorders	Extrapyramidal Disorders
# C0234987	Dizziness postural	Dizziness postural
# C0015376	Extravasation	Extravasation
# C0242979	Muscle Fatigue	Muscle Fatigue
# C0240182	Leukonychia	Leukonychia
# C0036202	Sarcoidosis	Sarcoidosis
# C0001396	Adams-Stokes Syndrome	Adams-Stokes Syndrome
# C0522178	Self-injurious ideation	Self-injurious ideation
# C0522179	Fear of death	Fear of death
# C0438235	Liver function test normal	Liver function test normal
# C0242225	Color blindness	Color blindness
# C0042029	Urinary tract infection	Urinary tract infection
# C0277890	Decreased diastolic arterial pressure	Decreased diastolic arterial pressure
# C0038325	Stevens-Johnson Syndrome	Stevens-Johnson Syndrome
# C0026857	Musculoskeletal Diseases	Musculoskeletal Diseases
# C0042024	Urinary Incontinence	Urinary Incontinence
# C0042023	Increased frequency of micturition	Increased frequency of micturition
# C0541799	Bad taste	Bad taste
# C0541798	Early Awakening	Early Awakening
# C0005741	Blepharitis	Blepharitis
# C0024121	Lung Neoplasms	Lung Neoplasms
# C0005747	Blepharospasm	Blepharospasm
# C0577559	Mass of body structure	Mass of body structure
# C0013687	Effusion	Effusion
# C0018188	Granuloma	Granuloma
# C0021845	Intestinal Perforation	Intestinal Perforation
# C0021843	Intestinal Obstruction	Intestinal Obstruction
# C0236024	Pharyngeal oedema	Pharyngeal oedema
# C0234930	Skin odour abnormal	Skin odour abnormal
# C2607914	Allergic rhinitis (disorder)	Allergic rhinitis (disorder)
# C0236023	Periodontal destruction	Periodontal destruction
# C3248383	Logorrhoea	Logorrhoea
# C0232744	Function liver decreased	Function liver decreased
# C0263540	Onychomadesis	Onychomadesis
# C0036117	Salmonella infections	Salmonella infections
# C0577730	Family stress	Family stress
# C0205204	Scab	Scab
# C0853879	Invasive Breast Carcinoma	Invasive Breast Carcinoma
# C1519353	Skin Papule	Skin Papule
# C0877167	Psychomotor skills impaired	Psychomotor skills impaired
# C0008049	Chickenpox	Chickenpox
# C0151723	Hypomagnesaemia	Hypomagnesaemia
# C0012797	Diuresis	Diuresis
# C0016034	Breast Fibrocystic Disease	Breast Fibrocystic Disease
# C0020546	Hypertensive crisis	Hypertensive crisis
# C0040479	Torsades de Pointes	Torsades de Pointes
# C0020545	Hypertension, Renovascular	Hypertension, Renovascular
# C0392171	Influenza-like symptoms	Influenza-like symptoms
# C0003044	Animal bite	Animal bite
# C0393760	Initial insomnia	Initial insomnia
# C0027066	Myoclonus	Myoclonus
# C0006384	Bundle-Branch Block	Bundle-Branch Block
# C0149931	Migraine Disorders	Migraine Disorders
# C0520463	Chronic active hepatitis	Chronic active hepatitis
# C0751901	Tic, Vocal	Tic, Vocal
# C0751900	Tic, Motor	Tic, Motor
# C1696943	Hypoaesthesia facial	Hypoaesthesia facial
# C0332575	Redness	Redness
# C0016927	Gagging	Gagging
# C0034065	Pulmonary Embolism	Pulmonary Embolism
# C2363731	Oropharyngeal pain	Oropharyngeal pain
# C0860661	Oppositional	Oppositional
# C1740801	Exaggerated startle response	Exaggerated startle response
# C1145670	Respiratory Failure	Respiratory Failure
# C0221392	Atrophic Vaginitis	Atrophic Vaginitis
# C0392197	Physiologic warmth	Physiologic warmth
# C0149732	Muscle rupture	Muscle rupture
# C0029077	Ophthalmia, Sympathetic	Ophthalmia, Sympathetic
# C0085655	Polymyositis	Polymyositis
# C0264907	Mobitz type I incomplete atrioventricular block	Mobitz type I incomplete atrioventricular block
# C0221150	Odynophagia	Odynophagia
# C0423791	Rash maculo-papular	Rash maculo-papular
# C0221155	Systolic hypertension	Systolic hypertension
# C0423798	Increased tendency to bruise	Increased tendency to bruise
# C0233514	Abnormal behavior	Abnormal behavior
# C0423006	Discharge from eye	Discharge from eye
# C0853084	High density lipoprotein increased	High density lipoprotein increased
# C0558919	Stress at work	Stress at work
# C0235774	Somnolence neonatal	Somnolence neonatal
# C0011860	Diabetes Mellitus, Non-Insulin-Dependent	Diabetes Mellitus, Non-Insulin-Dependent
# C0160390	Liver injury	Liver injury
# C0235827	Therapeutic response decreased	Therapeutic response decreased
# C0234428	Consciousness abnormal	Consciousness abnormal
# C0027849	Neuroleptic Malignant Syndrome	Neuroleptic Malignant Syndrome
# C0423773	Skin scaly	Skin scaly
# C0036439	Scoliosis, unspecified	Scoliosis, unspecified
# C0039446	Telangiectasis	Telangiectasis
# C0542351	Battery (assault)	Battery (assault)
# C2129214	Loose stool	Loose stool
# C2945586	Bladder irritability	Bladder irritability
# C0278701	Gastric Adenocarcinoma	Gastric Adenocarcinoma
# C0021141	Inappropriate ADH Syndrome	Inappropriate ADH Syndrome
# C1442903	Exostoses	Exostoses
# C0221714	Injection site infection	Injection site infection
# C0406479	Steroid acne	Steroid acne
# C0521839	Influenza like illness	Influenza like illness
# C0235919	Nerve root lesion	Nerve root lesion
# C0424091	Decreased interest	Decreased interest
# C0004601	Back Injuries	Back Injuries
# C0041834	Erythema	Erythema
# C0699744	Infection of ear	Infection of ear
# C0004604	Back Pain	Back Pain
# C0428196	Bicarbonate level	Bicarbonate level
# C1321905	Minimal Brain Dysfunction	Minimal Brain Dysfunction
# C1956415	Paroxysmal nocturnal dyspnea	Paroxysmal nocturnal dyspnea
# C0030201	Pain, Postoperative	Pain, Postoperative
# C0027819	Neuroblastoma	Neuroblastoma
# C0580493	Serum albumin low result	Serum albumin low result
# C0004936	Mental disorders	Mental disorders
# C0549475	Lipase increased	Lipase increased
# C0877221	Decreased erythroid precursor production	Decreased erythroid precursor production
# C0020039	Hostility	Hostility
# C0574960	Sacroiliitis	Sacroiliitis
# C0392176	Gastric irritation	Gastric irritation
# C0015300	Exophthalmos	Exophthalmos
# C0002940	Aneurysm	Aneurysm
# C0001546	Adjustment Disorders	Adjustment Disorders
# C0281963	Red cell aplasia	Red cell aplasia
# C0404521	Infective vaginitis	Infective vaginitis
# C0010034	Corneal Diseases	Corneal Diseases
# C0025287	Meningism	Meningism
# C0025281	Meniere Disease	Meniere Disease
# C0349506	Photosensitivity of skin	Photosensitivity of skin
# C0025289	Meningitis	Meningitis
# C0242172	Pelvic Inflammatory Disease	Pelvic Inflammatory Disease
# C0042345	Varicosity	Varicosity
# C0152459	Linear atrophy	Linear atrophy
# C0036690	Septicemia	Septicemia
# C0877359	Raised liver function tests	Raised liver function tests
# C0024137	Lupus Erythematosus, Cutaneous	Lupus Erythematosus, Cutaneous
# C0025517	Metabolic Diseases	Metabolic Diseases
# C0019917	Hordeolum	Hordeolum
# C0085136	Central Nervous System Neoplasms	Central Nervous System Neoplasms
# C0587246	Limb paresis	Limb paresis
# C0948216	Ovarian adenocarcinoma	Ovarian adenocarcinoma
# C0036104	Secretion of saliva	Secretion of saliva
# C0311220	Lymphocytoma cutis	Lymphocytoma cutis
# C0156369	Uterine Polyp	Uterine Polyp
# C0042164	Uveitis	Uveitis
# C0555724	On examination - dry lips	On examination - dry lips
# C0042167	Uveitis, Posterior	Uveitis, Posterior
# C0520878	Electrocardiogram PR shortened	Electrocardiogram PR shortened
# C0747979	Increased prolactin level	Increased prolactin level
# C0033046	Premenstrual syndrome	Premenstrual syndrome
# C0853644	Eosinophil count abnormal	Eosinophil count abnormal
# C0019825	Hoarseness	Hoarseness
# C0162533	Porphyrias, Hepatic	Porphyrias, Hepatic
# C0019048	Hemoglobinuria	Hemoglobinuria
# C1260880	Rhinorrhea	Rhinorrhea
# C0028734	Nocturia	Nocturia
# C1168401	Squamous cell carcinoma of the head and neck	Squamous cell carcinoma of the head and neck
# C0018081	Gonorrhea	Gonorrhea
# C0028738	Nystagmus	Nystagmus
# C0013781	Shock from electric current	Shock from electric current
# C0231686	Gait, Unsteady	Gait, Unsteady
# C1456865	Ureteral Calculi	Ureteral Calculi
# C0847631	Dry scalp	Dry scalp
# C2937358	Cerebral Hemorrhage	Cerebral Hemorrhage
# C0263449	Perioral Dermatitis	Perioral Dermatitis
# C0022081	Iritis	Iritis
# C2937350	Abnormal ejaculation	Abnormal ejaculation
# C2973529	Leukocytoclastic vasculitis	Leukocytoclastic vasculitis
# C0015726	Fear (Mental Process)	Fear (Mental Process)
# C0042769	Virus Diseases	Virus Diseases
# C0232487	Abdominal discomfort	Abdominal discomfort
# C3495917	Advanced breast cancer	Advanced breast cancer
# C0151588	Transitory deafness	Transitory deafness
# C0240211	Lip swelling	Lip swelling
# C0032064	Plague	Plague
# C0151586	Partial permanent deafness	Partial permanent deafness
# C0151580	Crystalluria calcium	Crystalluria calcium
# C3160887	Node-positive breast cancer	Node-positive breast cancer
# C3160889	Node-negative breast cancer	Node-negative breast cancer
# C3160888	Metastatic gastric adenocarcinoma	Metastatic gastric adenocarcinoma
# C0151908	Dry skin	Dry skin
# C0847033	Allergic oedema	Allergic oedema
# C0041582	Ulcer	Ulcer
# C0235218	Skin warm	Skin warm
# C0151905	Alanine aminotransferase increased	Alanine aminotransferase increased
# C0027609	Neonatal Abstinence Syndrome	Neonatal Abstinence Syndrome
# C0151907	Discoloration of skin	Discoloration of skin
# C0238111	Lennox-Gastaut syndrome	Lennox-Gastaut syndrome
# C0035317	Retinal Hemorrhage	Retinal Hemorrhage
# C0948011	Cervix haemorrhage uterine	Cervix haemorrhage uterine
# C0040485	Torticollis	Torticollis
# C0852932	Arthropod sting	Arthropod sting
# C0003834	Arterial insufficiency	Arterial insufficiency
# C0030528	Paratyphoid Fever	Paratyphoid Fever
# C0151763	Liver damage	Liver damage
# C0729552	Genital infection	Genital infection
# C0151765	Liver fatty deposition	Liver fatty deposition
# C0184567	Acute onset pain	Acute onset pain
# C0151766	Liver function tests abnormal finding	Liver function tests abnormal finding
# C1112209	Intraabdominal Infections	Intraabdominal Infections
# C0268000	Fluid retention	Fluid retention
# C1142034	Tandem gait test abnormal	Tandem gait test abnormal
# C0042907	Vitreous Detachment	Vitreous Detachment
# C0029464	Osteosclerosis	Osteosclerosis
# C0003615	Appendicitis	Appendicitis
# C0162835	Hypopigmentation disorder	Hypopigmentation disorder
# C0039338	Taste Disorders	Taste Disorders
# C1258215	Ileus	Ileus
# C0260662	Hearing problem	Hearing problem
# C0031039	Pericardial effusion	Pericardial effusion
# C0235369	Hepatitis granulomatous	Hepatitis granulomatous
# C0869523	Carditis	Carditis
# C0011071	Sudden death	Sudden death
# C0919591	Urogenital haemorrhage	Urogenital haemorrhage
# C0848377	Trauma to the abdomen	Trauma to the abdomen
# C0030781	Peliosis Hepatis	Peliosis Hepatis
# C0020555	Hypertrichosis	Hypertrichosis
# C0020557	Hypertriglyceridemia	Hypertriglyceridemia
# C0020550	Hyperthyroidism	Hyperthyroidism
# C0242292	McCune-Albright Syndrome	McCune-Albright Syndrome
# C0029882	Otitis Media	Otitis Media
# C0040147	Thyroiditis	Thyroiditis
# C0040460	Toothache	Toothache
# C0235146	Euphoric mood	Euphoric mood
# C0271240	Blindness of one eye (disorder)	Blindness of one eye (disorder)
# C0280100	Solid tumour	Solid tumour
# C0271710	Reactive hypoglycemia	Reactive hypoglycemia
# C0240671	Partial thromboplastin time increased (finding)	Partial thromboplastin time increased (finding)
# C0036416	Scleritis	Scleritis
# C0006663	Calcinosis	Calcinosis
# C0040997	Trigeminal Neuralgia	Trigeminal Neuralgia
# C0007820	Cerebrovascular Disorders	Cerebrovascular Disorders
# C0699828	Serotonin Syndrome	Serotonin Syndrome
# C0030567	Parkinson Disease	Parkinson Disease
# C1112573	Delayed orgasm	Delayed orgasm
# C0007286	Carpal Tunnel Syndrome	Carpal Tunnel Syndrome
# C0151757	Lenticular pigmentation	Lenticular pigmentation
# C0149707	Hemospermia	Hemospermia
# C0854097	Hypoesthesia eye	Hypoesthesia eye
# C0333291	Ulcer haemorrhage	Ulcer haemorrhage
# C0085669	Acute leukemia	Acute leukemia
# C0919661	Heart alternation	Heart alternation
# C0085660	Aseptic necrosis	Aseptic necrosis
# C0085661	Onycholysis	Onycholysis
# C0233523	Antisocial behavior	Antisocial behavior
# C0151818	Opisthotonus	Opisthotonus
# C0040517	Gilles de la Tourette syndrome	Gilles de la Tourette syndrome
# C1262036	Ocular toxicity	Ocular toxicity
# C1369037	FInding of estrangement	FInding of estrangement
# C0020488	Hypernatremia	Hypernatremia
# C0155866	Inhalational anthrax	Inhalational anthrax
# C0497156	Lymphadenopathy	Lymphadenopathy
# C0155862	Streptococcal pneumonia	Streptococcal pneumonia
# C0267596	Rectal hemorrhage	Rectal hemorrhage
# C0026986	Dysmyelopoietic Syndromes	Dysmyelopoietic Syndromes
# C0011253	Delusions	Delusions
# C0019559	Coxalgia	Coxalgia
# C0221706	Traffic accident on public road	Traffic accident on public road
# C0234238	Ache	Ache
# C0234233	Sore to touch	Sore to touch
# C0155919	Acute pulmonary oedema	Acute pulmonary oedema
# C0860654	Reduced interest in usual activities	Reduced interest in usual activities
# C0015468	Facial Pain	Facial Pain
# C1608954	Infusion site extravasation	Infusion site extravasation
# C0340865	Anaphylactoid reaction	Anaphylactoid reaction
# C0235969	Ejaculation disorder	Ejaculation disorder
# C0701810	Long-term memory loss	Long-term memory loss
# C0235966	Dreaming excessive	Dreaming excessive
# C0019693	HIV Infections	HIV Infections
# C0702266	Basophilia	Basophilia
# C0920063	Uric acid high	Uric acid high
# C0038013	Ankylosing spondylitis	Ankylosing spondylitis
# C0025218	Chloasma	Chloasma
# C0549264	Sensation of blood flow	Sensation of blood flow
# C0008449	Chondrodystrophy	Chondrodystrophy
# C0743668	Limb injury	Limb injury
# C0857751	Erythema multiforme minor	Erythema multiforme minor
# C0024419	Waldenstrom Macroglobulinemia	Waldenstrom Macroglobulinemia
# C0392386	Decreased platelet count	Decreased platelet count
# C0162532	Variegate Porphyria	Variegate Porphyria
# C0024031	Low Back Pain	Low Back Pain
# C0034735	Raynaud Phenomenon	Raynaud Phenomenon
# C0859023	Talkativeness	Talkativeness
# C0155003	Blindness, Transient	Blindness, Transient
# C0233651	Perseveration	Perseveration
# C1141893	Muscle enzyme increased	Muscle enzyme increased
# C0424790	Rigor - Temperature-associated observation	Rigor - Temperature-associated observation
# C0001577	Adnexitis	Adnexitis
# C3495440	Break-through bleeding (finding)	Break-through bleeding (finding)
# C0025290	Aseptic Meningitis	Aseptic Meningitis
# C0042594	Vestibular Diseases	Vestibular Diseases
# C0856081	Restlessness aggravated	Restlessness aggravated
# C0277889	Blood pressure diastolic increased	Blood pressure diastolic increased
# C0019214	Hepatosplenomegaly	Hepatosplenomegaly
# C0152115	Lingual-Facial-Buccal Dyskinesia	Lingual-Facial-Buccal Dyskinesia
# C0578687	Sore eye	Sore eye
# C0857353	Hypotensive	Hypotensive
# C0155713	Papillary muscle rupture	Papillary muscle rupture
# C0277885	Blood pressure systolic decreased	Blood pressure systolic decreased
# C0277884	Blood pressure systolic increased	Blood pressure systolic increased
# C0025500	Mesothelioma	Mesothelioma
# C0015408	Eye Injuries	Eye Injuries
# C0014130	Endocrine System Diseases	Endocrine System Diseases
# C0151885	Reaction aggravation	Reaction aggravation
# C0015403	Eye Infections	Eye Infections
# C0015402	Eye Hemorrhage	Eye Hemorrhage
# C0042571	Vertigo	Vertigo
# C0234894	Dermatitis acneiform	Dermatitis acneiform
# C0040264	Tinnitus	Tinnitus
# C0236000	Jaw pain	Jaw pain
# C0237849	Peeling of skin	Peeling of skin
# C0349208	Manic episode	Manic episode
# C0019079	Hemoptysis	Hemoptysis
# C0014553	Absence Epilepsy	Absence Epilepsy
# C0014550	Epilepsies, Myoclonic	Epilepsies, Myoclonic
# C0520886	ST segment elevation (finding)	ST segment elevation (finding)
# C0520888	Inverted T wave	Inverted T wave
# C0025345	Menstruation Disturbances	Menstruation Disturbances
# C0018099	Gout	Gout
# C1861172	Venous Thromboembolism	Venous Thromboembolism
# C0022346	Icterus	Icterus
# C1260899	Anemia, Diamond-Blackfan	Anemia, Diamond-Blackfan
# C0003537	Aphasia	Aphasia
# C0860700	Prothrombin level abnormal	Prothrombin level abnormal
# C0687713	Gastrointestinal pain	Gastrointestinal pain
# C0152936	Plague, Septicemic	Plague, Septicemic
# C0428886	Mean blood pressure	Mean blood pressure
# C0853692	Blood triglycerides increased	Blood triglycerides increased
# C0853697	Neutrophil count decreased	Neutrophil count decreased
# C0239340	Edema of lower extremities	Edema of lower extremities
# C0152169	Renal Colic	Renal Colic
# C0232498	Abdominal tenderness	Abdominal tenderness
# C0232495	Abdominal pain lower	Abdominal pain lower
# C0262988	Cutaneous vasculitis	Cutaneous vasculitis
# C0232492	Abdominal pain upper	Abdominal pain upper
# C0151571	Corneal lesion	Corneal lesion
# C0039231	Tachycardia	Tachycardia
# C0151574	Cough decreased	Cough decreased
# C0151576	Creatine phosphokinase increased	Creatine phosphokinase increased
# C0151577	Creatinine renal clearance decreased	Creatinine renal clearance decreased
# C0151578	Creatinine increased	Creatinine increased
# C0151579	Crystalluria	Crystalluria
# C0039239	Sinus Tachycardia	Sinus Tachycardia
# C0231441	Immobile	Immobile
# C0346156	Benign neoplasm of breast	Benign neoplasm of breast
# C0032584	Polyps	Polyps
# C0521591	Paraesthesia oral	Paraesthesia oral
# C0521592	Hypoaesthesia oral	Hypoaesthesia oral
# C0920163	Idiopathic thrombocytopenia	Idiopathic thrombocytopenia
# C0549447	Urine odour foul	Urine odour foul
# C0041956	Ureteral obstruction	Ureteral obstruction
# C0221345	Nail discoloration	Nail discoloration
# C0036974	Shock	Shock
# C0007773	Cerebral arteritis	Cerebral arteritis
# C0010692	Cystitis	Cystitis
# C0036973	Shivering	Shivering
# C0267158	Reflux gastritis	Reflux gastritis
# C1302752	Abrasion	Abrasion
# C0016412	Folic Acid Deficiency	Folic Acid Deficiency
# ...
# C0043094	Weight Gain	Weight Gain
# C0232461	Increased appetite (finding)	literally eaten a whole pizza
# C0232461	Increased appetite (finding)	Increased appetite (finding)
# C0455769	Energy increased	got me to the ceiling
# C0455769	Energy increased	Energy increased
# C0221170	Muscular stiffness	numbness
# C0221170	Muscular stiffness	Muscular stiffness
# C0233479	Elevated mood	feeling good
# C0233479	Elevated mood	Elevated mood
# C0338614	Psychotic episode	MY MIND IS GONE
# C0338614	Psychotic episode	Psychotic episode
# C0392674	Exhaustion	sleep deprived
# C0392674	Exhaustion	Exhaustion
# C2830004	Somnolence	knocked me out
# C2830004	Somnolence	Somnolence
# C0853348	Arthropod bite	chiggers
# C0853348	Arthropod bite	Arthropod bite
# C0020604	Hypochondriasis	up for 4 days
# C0020604	Hypochondriasis	Hypochondriasis
# C1443060	Feeling abnormal	feeling awful
# C1443060	Feeling abnormal	Feeling abnormal
# C3536794	Sad mood	Sad mood
# C0018524	Hallucinations	bazaar thoughts
# C0018524	Hallucinations	Hallucinations
# C0018524	Hallucinations	1pm to 3am real quick
# C0018524	Hallucinations	Hallucinations
# C2939186	Disturbance in mood	had me in my feelings
# C2939186	Disturbance in mood	Disturbance in mood
# C0022107	Irritable Mood	resting bitch face
# C0022107	Irritable Mood	Irritable Mood
# C0027932	Neurotic Disorders	Neurotic Disorders
# C0030252	Palpitations	heart palpitations
# C0030252	Palpitations	Palpitations
# C0235169	Excitability	in my feelings
# C0235169	Excitability	Excitability
# C0027497	Nausea	wanted to vent
# C0027497	Nausea	Nausea
# C0034634	Rage	mad
# C0034634	Rage	Rage
# C0036974	Shock	Weird full body electrical shocks
# C0036974	Shock	Shock
# C0027769	Nervousness	twitchy
# C0027769	Nervousness	Nervousness
# C0424295	Hyperactive behavior	has me like
# C0424295	Hyperactive behavior	Hyperactive behavior
# C0235169	Excitability	got me in my feelings
# C0235169	Excitability	Excitability
# C0006370	Bulimia	Bulimia
# C0018524	Hallucinations	permanent hallucinations
# C0018524	Hallucinations	Hallucinations
# C0018834	Heartburn	heartburn
# C0018834	Heartburn	Heartburn
# C0393760	Initial insomnia	I CANT SLEEP
# C0393760	Initial insomnia	Initial insomnia
# C0728899	Intoxication	groggy
# C0728899	Intoxication	Intoxication
# C0393760	Initial insomnia	wide awake
# C0393760	Initial insomnia	Initial insomnia
# C0152128	Drug withdrawal syndrome	Drug withdrawal syndrome
# C0040822	Tremor	can't stop shaking
# C0040822	Tremor	Tremor
# C0917801	Sleeplessness	Wide awake
# C0917801	Sleeplessness	Sleeplessness
# C0700590	Increased sweating	sweat
# C0700590	Increased sweating	Increased sweating
# C0030193	Pain	get rid of the pain
# C0030193	Pain	Pain
# C0393760	Initial insomnia	#insomnia
# C0393760	Initial insomnia	Initial insomnia
# C0270458	Psychotic depression	Psychotic depression
# C0393761	Middle insomnia	insomniac
# C0393761	Middle insomnia	Middle insomnia
# C0393760	Initial insomnia	Insomnia
# C0393760	Initial insomnia	Initial insomnia
# C0393761	Middle insomnia	insomnia
# C0393761	Middle insomnia	Middle insomnia
# C0700590	Increased sweating	sweating bullets
# C0700590	Increased sweating	Increased sweating
# C0858899	Attention concentration difficulty	procrastinating
# C0858899	Attention concentration difficulty	Attention concentration difficulty
# C0234894	Dermatitis acneiform	acne
# C0234894	Dermatitis acneiform	Dermatitis acneiform
# C0235146	Euphoric mood	GETTING HIGH
# C0235146	Euphoric mood	Euphoric mood
# C0917801	Sleeplessness	got me uppppp
# C0917801	Sleeplessness	Sleeplessness
# C0087169	Withdrawal Symptoms	Withdrawal Symptoms
# C0233632	Disturbance in thinking	thinking it was 8pm
# C0233632	Disturbance in thinking	Disturbance in thinking
# C0022107	Irritable Mood	Irritable Mood
# C0152128	Drug withdrawal syndrome	Drug withdrawal syndrome
# C0151763	Liver damage	probs with my liver
# C0151763	Liver damage	Liver damage
# C0028643	Numbness	can't feel limbs
# C0028643	Numbness	Numbness
# C0497364	Localized rash	Rash
# C0497364	Localized rash	Localized rash
# C0455769	Energy increased	strengthens me
# C0455769	Energy increased	Energy increased
# C0344320	Vivid dreams	mad vivid dreams
# C0344320	Vivid dreams	Vivid dreams
# C0043094	Weight Gain	Weight Gain
# C0393760	Initial insomnia	Initial insomnia
# C0022107	Irritable Mood	mean
# C0022107	Irritable Mood	Irritable Mood
# C0600104	Obsessive compulsive behavior	have no choice but clean the house
# C0600104	Obsessive compulsive behavior	Obsessive compulsive behavior
# C0030319	Panic Disorder	Panic Disorder
# C0043094	Weight Gain	gaining weight
# C0043094	Weight Gain	Weight Gain
# C0039971	Thirst	dry
# C0039971	Thirst	Thirst
# C0424295	Hyperactive behavior	Hyperactive behavior
# C0006325	Bruxism	grinding my teeth
# C0006325	Bruxism	Bruxism
# C0043012	Wakefulness	wireddddddd
# C0043012	Wakefulness	Wakefulness
# C0027497	Nausea	Nausea
# C0013144	Drowsiness	still tired
# C0013144	Drowsiness	Drowsiness
# C0855242	Disturbance in sexual arousal	low libido
# C0855242	Disturbance in sexual arousal	Disturbance in sexual arousal
# C0234458	Abnormal dreams	#messed
# C0234458	Abnormal dreams	Abnormal dreams
# C0086132	Depressive Symptoms	loneliness
# C0086132	Depressive Symptoms	Depressive Symptoms
# C2939186	Disturbance in mood	today i think i'm hilarious
# C2939186	Disturbance in mood	Disturbance in mood
# C0030583	Parotitis	parotid gland swelling
# C0030583	Parotitis	Parotitis
# C0021368	Inflammation	Inflammation
# C2939186	Disturbance in mood	mood swings
# C2939186	Disturbance in mood	Disturbance in mood
# C0344315	Depressed mood	miserable
# C0344315	Depressed mood	Depressed mood
# C0151786	Muscle Weakness	weak
# C0151786	Muscle Weakness	Muscle Weakness
# C0087169	Withdrawal Symptoms	withdrawal
# C0087169	Withdrawal Symptoms	Withdrawal Symptoms
# C0040822	Tremor	shaking
# C0040822	Tremor	Tremor
# C0043094	Weight Gain	pre-prozac-weight-gain-nightmare
# C0043094	Weight Gain	Weight Gain
# C0423757	Skin thinness	thinning skin
# C0423757	Skin thinness	Skin thinness
# C0278061	Abnormal mental state	feel weird
# C0278061	Abnormal mental state	Abnormal mental state
# C0085633	Mood swings	dramatic
# C0085633	Mood swings	Mood swings
# C0015672	Fatigue	tired
# C0015672	Fatigue	Fatigue
# C0041671	Attention Deficit Disorder	ADD prevents me from focusing
# C0041671	Attention Deficit Disorder	Attention Deficit Disorder
# C0015672	Fatigue	Fatigue
# C0013144	Drowsiness	ready for a nap
# C0013144	Drowsiness	Drowsiness
# C0344315	Depressed mood	#CantWin
# C0344315	Depressed mood	Depressed mood
# C0233414	Disturbance in attention	getting distracted every 5 minutes
# C0233414	Disturbance in attention	Disturbance in attention
# C0233459	Emotional disorder	emotionally numb
# C0233459	Emotional disorder	Emotional disorder
# C0027497	Nausea	sick
# C0027497	Nausea	Nausea
# C1263846	Attention deficit hyperactivity disorder	ADHD
# C1263846	Attention deficit hyperactivity disorder	Attention deficit hyperactivity disorder
# C0009676	Confusion	confused
# C0009676	Confusion	Confusion
# C0005586	Bipolar Disorder	#bipolar
# C0005586	Bipolar Disorder	Bipolar Disorder
# C0085633	Mood swings	had me in my feelings
# C0085633	Mood swings	Mood swings
# C0041671	Attention Deficit Disorder	ADD
# C0041671	Attention Deficit Disorder	Attention Deficit Disorder
# C0151836	Paranoid reaction	paranoid
# C0151836	Paranoid reaction	Paranoid reaction
# C0235169	Excitability	in my feelings
# C0235169	Excitability	Excitability
# C1510472	Drug Dependence	Drug Dependence
# C0522224	Paralysed	paralyzed
# C0522224	Paralysed	Paralysed
# C0087169	Withdrawal Symptoms	withdrawal symptoms
# C0087169	Withdrawal Symptoms	Withdrawal Symptoms
# C2939186	Disturbance in mood	Disturbance in mood
# C0522172	Feeling drunk	feel drunk
# C0522172	Feeling drunk	Feeling drunk
# C1971624	Loss of appetite (finding)	barley eating
# C1971624	Loss of appetite (finding)	Loss of appetite (finding)
# C0003467	Anxiety	anxiety
# C0003467	Anxiety	Anxiety
# C0152031	Joint swelling	Joint was super swollen
# C0152031	Joint swelling	Joint swelling
# C0393761	Middle insomnia	keeping me awake
# C0393761	Middle insomnia	Middle insomnia
# C0220870	Lightheadedness	dizziness
# C0220870	Lightheadedness	Lightheadedness
# C0235195	Sedated state	calms me down
# C0235195	Sedated state	Sedated state
# C0040822	Tremor	jitters
# C0040822	Tremor	Tremor
# C0235169	Excitability	got me to the ceiling
# C0235169	Excitability	Excitability
# C0234987	Dizziness postural	not falling down dizzy
# C0234987	Dizziness postural	Dizziness postural
# C0043387	Yawning	yawns
# C0043387	Yawning	Yawning
# C0541799	Bad taste	mouth taste terrible
# C0541799	Bad taste	Bad taste
# C0858899	Attention concentration difficulty	doesn't even make me attentive
# C0858899	Attention concentration difficulty	Attention concentration difficulty
# C0042256	Vaginal itching	itching
# C0042256	Vaginal itching	Vaginal itching
# C0917801	Sleeplessness	Sleeplessness
# C0235169	Excitability	got me to the ceiling
# C0235169	Excitability	Excitability
# C0917799	Hypersomnia	sleep for 16 hours a day
# C0917799	Hypersomnia	Hypersomnia
# C0278061	Abnormal mental state	bonkers
# C0278061	Abnormal mental state	Abnormal mental state
# C0393760	Initial insomnia	insomnia
# C0393760	Initial insomnia	Initial insomnia
# C0004936	Mental disorders	MY MIND IS GONE
# C0004936	Mental disorders	Mental disorders
# C0006370	Bulimia	bulimia
# C0006370	Bulimia	Bulimia
# C0005586	Bipolar Disorder	#bipolar
# C0005586	Bipolar Disorder	Bipolar Disorder
# C0541854	Daytime sleepiness	zombies
# C0541854	Daytime sleepiness	Daytime sleepiness
# C0004604	Back Pain	back ache
# C0004604	Back Pain	Back Pain
# C0043012	Wakefulness	trying to get tired
# C0043012	Wakefulness	Wakefulness
# C0000737	Abdominal Pain	pain in the pit of my stomach
# C0000737	Abdominal Pain	Abdominal Pain
# C0028643	Numbness	numbness
# C0028643	Numbness	Numbness
# C0700031	Anxiety attack	panic attacks
# C0700031	Anxiety attack	Anxiety attack
# C0086769	Panic Attacks	panic attacks
# C0086769	Panic Attacks	Panic Attacks
# C0541854	Daytime sleepiness	walking zombie
# C0541854	Daytime sleepiness	Daytime sleepiness
# C0043012	Wakefulness	still got me up
# C0043012	Wakefulness	Wakefulness
# C0086769	Panic Attacks	panic attack
# C0086769	Panic Attacks	Panic Attacks
# C0087169	Withdrawal Symptoms	withdrawals
# C0087169	Withdrawal Symptoms	Withdrawal Symptoms
# C0030193	Pain	feel like I was hit by a train.
# C0030193	Pain	Pain
# C0038587	Substance Withdrawal Syndrome	cigarette withdrawal
# C0038587	Substance Withdrawal Syndrome	Substance Withdrawal Syndrome
# C0012833	Dizziness	head spinning a little
# C0012833	Dizziness	Dizziness
# C0043012	Wakefulness	awake approx 36-38 hours
# C0043012	Wakefulness	Wakefulness
# C0003467	Anxiety	I'm scared
# C0003467	Anxiety	Anxiety
# C0030193	Pain	pain
# C0030193	Pain	Pain
# C0152128	Drug withdrawal syndrome	tapering off prednisone
# C0152128	Drug withdrawal syndrome	Drug withdrawal syndrome
#
#                       ID                  Concept    Description
# 0               76376003  Endometriosis of uterus    adenomyosis
# 1              399153001                  Vertigo        vertigo
# 2       3877011000036101                  Lipitor        LIPITOR
# 3               68962001                  Myalgia    muscle pain
# 4               57676002               Arthralgia     joint pain
# ...                  ...                      ...            ...
# 344125          76948002              Severe pain    pain severe
# 344126          68962001                  Myalgia  muscels hurts
# 344127          52613005       Excessive sweating  sweating alot
# 344128          68962001                  Myalgia   muscle aches
# 344129          37796009                 Migraine       migraine
#
# [344130 rows x 3 columns]
#               ID                   Concept                        Description
# 0       C0455769          Energy increased                    still not tired
# 1       C0011991                  Diarrhea                           diarrhea
# 2       C0087169       Withdrawal Symptoms              Miss your Prozac does
# 3       C0424295      Hyperactive behavior  unnecessarily wipe for 20 minutes
# 4       C0003123                  Anorexia          I haven't eaten in 3 days
# ...          ...                       ...                                ...
# 100048  C0003467                   Anxiety                            Anxiety
# 100049  C0030193                      Pain                               pain
# 100050  C0030193                      Pain                               Pain
# 100051  C0152128  Drug withdrawal syndrome            tapering off prednisone
# 100052  C0152128  Drug withdrawal syndrome           Drug withdrawal syndrome
#
# [100053 rows x 3 columns]
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 344125     True
# 344126     True
# 344127     True
# 344128     True
# 344129     True
# Length: 344130, dtype: bool
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100048     True
# 100049     True
# 100050     True
# 100051     True
# 100052     True
# Length: 100053, dtype: bool
#                       ID  ...                            Description
# 0               76376003  ...                            adenomyosis
# 1              399153001  ...                                vertigo
# 2       3877011000036101  ...                                LIPITOR
# 3               68962001  ...                            muscle pain
# 4               57676002  ...                             joint pain
# ...                  ...  ...                                    ...
# 99443           57676002  ...                   Minor joint soreness
# 99453          424196004  ...                                jittery
# 99538           55300003  ...                          muscle spasms
# 171543          95847005  ...  permanent, irreversible muscle damage
# 171954          55300003  ...                          mussel spasms
#
# [5065 rows x 3 columns]
#              ID               Concept                        Description
# 0      C0455769      Energy increased                    still not tired
# 1      C0011991              Diarrhea                           diarrhea
# 2      C0087169   Withdrawal Symptoms              Miss your Prozac does
# 3      C0424295  Hyperactive behavior  unnecessarily wipe for 20 minutes
# 4      C0003123              Anorexia          I haven't eaten in 3 days
# ...         ...                   ...                                ...
# 10527  C0022107        Irritable Mood                            asshole
# 10545  C0003467               Anxiety                      scared/unsure
# 10563  C0522172         Feeling drunk                    make me drunker
# 10698  C0917801         Sleeplessness                      got me uppppp
# 10837  C0917799           Hypersomnia           sleep for 16 hours a day
#
# [3204 rows x 3 columns]
#                       ID  ...                Description
# 1              399153001  ...                    vertigo
# 2       3877011000036101  ...                    LIPITOR
# 3               68962001  ...                muscle pain
# 4               57676002  ...                 joint pain
# 7              271587009  ...  body stiffed during sleep
# ...                  ...  ...                        ...
# 57037  77424011000036100  ...                      C Q10
# 61478          162076009  ...                   GI bleed
# 61980            8943002  ...                wieght gain
# 63227          102556003  ...             pain in my arm
# 65062  21930011000036101  ...                      ZETIA
#
# [3177 rows x 3 columns]
#              ID               Concept                        Description
# 0      C0455769      Energy increased                    still not tired
# 2      C0087169   Withdrawal Symptoms              Miss your Prozac does
# 3      C0424295  Hyperactive behavior  unnecessarily wipe for 20 minutes
# 5      C0424295  Hyperactive behavior                          FUCKED UP
# 6      C2939186   Disturbance in mood              had me in my feelings
# ...         ...                   ...                                ...
# 10408  C2830004            Somnolence         constantly being so sleepy
# 10426  C0541854    Daytime sleepiness                    ready for a nap
# 10527  C0022107        Irritable Mood                            asshole
# 10545  C0003467               Anxiety                      scared/unsure
# 10698  C0917801         Sleeplessness                      got me uppppp
#
# [758 rows x 3 columns]

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive
